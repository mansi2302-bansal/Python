# %%
class Node:
  def __init__(self,data,next):
    self.data = data
    self.next = None

class linked_list:
  def __init__(self):
    self.head = None
    self.tail = None

  # The insert_at_end method should be at the same indentation level as the __init__ method.
  def insert_at_end(self,data):
    new_node = Node(data,None)
    if self.head == None:   # check if list is empty
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next =new_node
      self.tail = new_node

  def insert_at_end(self,data):
    new_node = Node(data,None)
    if self.head == None:   # check if list is empty
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next =new_node
      self.tail = new_node

  def insert_at_head(self,data):
    new_node = Node(data,None)
    if self.head == None:
      self.head = new_node
      self.tail = new_node
    else:
      new_node.next = self.head
      self.head = new_node

  def traverse(self):
    if self.head == None:
      print("list is empty")
    else:
      temp = self.head
      while temp != None:
        print(temp.data,end = " ")
        temp = temp.next

  def reverse_iterative(self):
    prev = None
    cur = self.head
    while cur:
      nxt = cur.next
      cur.next = prev
      prev = cur
      cur = nxt
    self.head = prev


a = linked_list()
my_node = Node(10,None)
a.insert_at_end(10)
a.insert_at_end(20)
a.insert_at_end(30)
a.insert_at_head(45)
a.traverse()
print("\n")
print("reversed list - ")
a.reverse_iterative()
a.traverse()
# Out:
# 45 10 20 30
#
# reversed list -
# 30 20 10 45

# %%
class Node:
  def __init__(self,data,next):
    self.data = data
    self.next = None

class linked_list:
  def __init__(self):
    self.head = None
    self.tail = None

  # The insert_at_end method should be at the same indentation level as the __init__ method.
  def insert_at_end(self,data):
    new_node = Node(data,None)
    if self.head == None:   # check if list is empty
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next =new_node
      self.tail = new_node

  def insert_at_end(self,data):
    new_node = Node(data,None)
    if self.head == None:   # check if list is empty
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next =new_node
      self.tail = new_node

  def insert_at_head(self,data):
    new_node = Node(data,None)
    if self.head == None:
      self.head = new_node
      self.tail = new_node
    else:
      new_node.next = self.head
      self.head = new_node

  def traverse(self):
    if self.head == None:
      print("list is empty")
    else:
      temp = self.head
      while temp != None:
        print(temp.data,end = " ")
        temp = temp.next

  def swapNodes(self, x, y):
      if x == y:
        return

      prevX = None
      currX = self.head
      while currX != None and currX.data != x:
        prevX = currX
        currX = currX.next

      prevY = None
      currY = self.head
      while currY != None and currY.data != y:
        prevY = currY
        currY = currY.next

      if currX == None or currY == None:
        return


      if prevX != None:
        prevX.next = currY

      else:
        self.head = currY

      if prevY != None:
        prevY.next = currX
      else:

        self.head = currX

      temp = currX.next
      currX.next = currY.next
      currY.next = temp

a = linked_list()
for i in range(1,11):
  if i%2 == 0:
    a.insert_at_head(i)
  else:
    a.insert_at_end(i)
a.traverse()
print("\n")
print("swapped: ")
a.swapNodes(4,8)
a.traverse()
# Out:
# 10 8 6 4 2 1 3 5 7 9
#
# swapped:
# 10 4 6 8 2 1 3 5 7 9
