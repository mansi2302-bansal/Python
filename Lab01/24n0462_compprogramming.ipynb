# %%
n = int(input("enter a number: "))
fact = 1
i=1
while i<=n:
  fact = fact*i
  i=i+1
print("factorial is ",fact)
# Out:
# enter a number: 4
# factorial is  24

# %%
array = [1,89,90,24,32]
mylist = []
for i in range(len(array)):
  if array[i]<array[i-1]:
    mylist.append(array)
print(mylist)
# Out:
# [[1, 89, 90, 24, 32], [1, 89, 90, 24, 32]]

# %%
array = []
n = int(input("enter number of elements"))
for i in range(n):
  x = input("enter the number")
  array.append(x)
print(array)
# Out:
# enter number of elements3
# enter the number23
# enter the number34
# enter the number45
# ['23', '34', '45']
