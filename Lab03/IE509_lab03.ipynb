# %%
def binary_search(arr,target):
  start = 0
  end = len(arr) - 1

  while start<=end:
    mid_val = (start+end)//2
    if arr[mid_val] == target:
      return mid_val
    elif arr[mid_val]<target:
      start = mid_val + 1
    else:
      end = mid_val - 1
  return -1

  for i in range(a,len(arr)):
  ceiling = arr[0]
  if arr[a]>arr[a+1]:
    ceiling = arr[a]
  return ceiling
a = ceiling_val([1,2,3,4,5,8,9],5)
b = ceiling_val([1,2,3,4,5,8,9],6)
# Out:
# 5

# %%
Q2
list1 = [1,2,3,4,5,6]
