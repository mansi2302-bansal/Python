# %% [markdown]
# 1. LINTING : it is an automated process of detecting errors in a program without executing the program on vs code , it is basically an extension
# 2. Formatpep8 : extension for formatting the code
# 3. Format on Save

# %% [markdown]
# 1. **Compiler**: Is a software program that translates human readable code into low level machine code 0s and 1s
# 2. While VS Code is just an editor that requires you to install a compiler separately, an IDE is an "all-in-one" suite that usually works right out of the box.

# %%
x = 1000
# this variable is like a label for the memoryy location that is assigned to the number
# Variables are used to store data in computer's memory.
#  make sure your variable names are descriptive and makes sense

# %%
def func()
# function is a piece of code that could be used again and again

# %% [markdown]
# Types of functions
# 1. Built in func
# 2. User Defined fns

# %% [markdown]
# DATA TYPES
# 1. String : slicing (xtracting a subsection from the string) /indexing (extracting a character from the string)
# 2. Numeric : int, float, complex
# 3. boolean

# %%
ord("B")
# Out:
# 66

# %%
## slicing and indexing
st = "python"
st[0:3]
# Out:
# 'pyt'

# %%
st[:-1]
# Out:
# 'pytho'

# %%
st[0:]
# Out:
# 'pyt'

# %%
## format string
first = "mansi"
last = "bansal"
s = f"{first} {last}"
s
# Out:
# 'mansi bansal'

# %%
## first.  , we can se all the methods associated with the string

# %%
first.replace("m","j")
# Out:
# 'jansi'

# %%
print("an" in first)
# Out:
# True

# %%
# complex numbers
x = 1+2j

# %%
type(x)
# Out:
# complex

# %%
x += 3
x
# Out:
# (7+2j)

# %%
## math module
import math
# math is an object and we can use the dot method to see all the methods

# %%
x.conjugate()
# Out:
# (7-2j)

# %%
x.imag
# Out:
# 2.0

# %%
math.ceil(x.real)
# Out:
# 7

# %%
## Data types
int(x.real)
# Out:
# 7

# %%
bool(0)
# Out:
# False

# %%
y = 2.3

# %%
int(y)
# Out:
# 2

# %%
float(y)
# Out:
# 2.3

# %%
str(y)
# Out:
# '2.3'

# %%
bool(x)
# Out:
# True

# %%
bool(6)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
# so we get false only when 0 or empty string or non-object

# %%
bool(" ")
# Out:
# True

# %%
bool("sewfs")
# Out:
# True

# %% [markdown]
# 1. **Operators** : + , - , * , / , // , % , **
# 2. **Comparision operators** : <, >, = , >= , <=, == , !=

# %%
## comparision operators
"bag" == "BAG"
# Out:
# False

# %%
ord("b")
# Out:
# 98

# %% [markdown]
#  **Conditional Statements**
#  1. if, elif, else

# %% [markdown]
# **Logical Operators** : and , or , not

# %% [markdown]
# 1. **and** : with and opertaor if both the conditions are true result will be true

# %%
age = 22
message = "eligible" if age>=18 else "Not eligible"

# %%
message
# Out:
# 'eligible'

# %%
## and
high_income = True
good_credit = False
if high_income and good_credit:
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Not eligible

# %%
student = True
if (high_income or good_credit) and not student:
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Not eligible

# %%
student = True
if (high_income and good_credit) and not student:   # as soon as even one of them is false the answer will be false
# if high incom is false it does not matter what the next condition is the entire result will be false , this is called shortcircuiting
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Not eligible

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
if high_income or good_credit:
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Eligible

# %% [markdown]
# **Loops**

# %%
for i in range(1,10,2): # 2 is the step / the gap b/w two nos
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# **Iterables in for loops**
# 1. we cann iterate over strings, lists, tuples, dictionaries

# %%
number = 100        # here we are not iterating over an iterable instead we are evaluating a condition.
while number > 0:
  print(number)
  number //= 2
# Out:
# 100
# 50
# 25
# 12
# 6
# 3
# 1
