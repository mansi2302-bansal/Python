# %%
class result:
  def __init__(self,rollno,name,marks):
    self.rollno = int(input("enter rollno: "))
    self.name = input("enter name: ")
    self.marks = []
  def display_info(self):
    self.marks = []
    for i in range(4):
      a = input("enter marks")
      a.append(marks)
  def show_marks(self):
    marks.show()
  def total_marks(self):
    total = 0
    for i in range(4):
      marks[i] = marks[i]+total
    print(total)
  def avg_marks(self):
    avg = total/3
    print(avg)


std = result(24,"mansi",10)
# Out:
# enter rollno: 11
# enter name: 11
